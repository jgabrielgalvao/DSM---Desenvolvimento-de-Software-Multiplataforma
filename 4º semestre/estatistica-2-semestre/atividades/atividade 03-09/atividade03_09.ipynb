# %%
import pandas as pd
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

# %%
NHE = pd.read_excel('/content/ex-1.xlsx')

# %%
NHE.describe()
# Out:
#            Tempo
# count  12.000000
# mean   18.416667
# std     2.539088
# min    16.000000
# 25%    16.000000
# 50%    17.500000
# 75%    20.250000
# max    23.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4['Tempo'].plot(kind='hist', bins=20, title='Tempo')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['Tempo'].plot(kind='line', figsize=(8, 4), title='Tempo')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
CV = (2.53 / 18.41) * 100
print(CV)
# Out:
# 13.74253123302553

# %%
NHE2 = pd.read_excel('/content/ex-2.xlsx')

# %%
NHE2.describe()
# Out:
#        Número de Publicações
# count              40.000000
# mean                1.950000
# std                 1.218448
# min                 0.000000
# 25%                 1.000000
# 50%                 2.000000
# 75%                 3.000000
# max                 4.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2['Número de Publicações'].plot(kind='hist', bins=20, title='Número de Publicações')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['Número de Publicações'].plot(kind='line', figsize=(8, 4), title='Número de Publicações')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
CV2 = (1.21 / 1.95) * 100
print(CV2)
# Out:
# 62.05128205128205

# %%
NHE3 = pd.read_excel('/content/ex-3.xlsx')

# %%
NHE3.describe()
# Out:
#        Salário Mínimos
# count       200.000000
# mean          6.500000
# std           3.646434
# min           1.000000
# 25%           3.000000
# 50%           7.000000
# 75%           9.000000
# max          13.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Salário Mínimos'].plot(kind='hist', bins=20, title='Salário Mínimos')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Salário Mínimos'].plot(kind='line', figsize=(8, 4), title='Salário Mínimos')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
CV3 = (3.64 / 6.50) * 100
print(CV3)
# Out:
# 56.00000000000001
